# %%
import matplotlib.pyplot as plt # type: ignore
import pandas as pd # type: ignore

# %%
df = pd.read_csv('bikessales_olap.salesorder.csv')
df
# Out:
#                            _id  salesorderid  salesorderitem productid  \
# 0     66678e7369ed4c2c204958f3     500000000              10   MB-1034
# 1     66678e7369ed4c2c204958f4     500000017              60   MB-1034
# 2     66678e7369ed4c2c204958f5     500000024              50   MB-1034
# 3     66678e7369ed4c2c204958f6     500000124             100   MB-1034
# 4     66678e7369ed4c2c204958f7     500000129              50   MB-1034
# ...                        ...           ...             ...       ...
# 997   66678e7369ed4c2c20495cd8     500000699              20   RO-1003
# 998   66678e7369ed4c2c20495cd9     500000741              20   RO-1003
# 999   66678e7369ed4c2c20495cda     500000857              10   RO-1003
# 1000  66678e7369ed4c2c20495cdb     500000886              80   RO-1003
# 1001  66678e7369ed4c2c20495cdc     500000992              20   RO-1003
#
#       quantity  weightmeasure weightunit currency  price  grossamount  \
# 0            4           12.5         KG      USD   2499        13587
# 1            3           12.5         KG      USD   2499        75228
# 2           10           12.5         KG      USD   2499        95368
# 3           10           12.5         KG      USD   2499        71289
# 4            8           12.5         KG      USD   2499       109947
# ...        ...            ...        ...      ...    ...          ...
# 997         10            9.1         KG      USD    721        54990
# 998          5            9.1         KG      USD    721        49093
# 999          4            9.1         KG      USD    721        20880
# 1000        10            9.1         KG      USD    721         1245
# 1001         5            9.1         KG      USD    721        44294
#
#       taxamount  netamount language       medium_descr    short_descr  \
# 0      1698.375  11888.625       EN  Mt Discovery Ulti  Mountain Bike
# 1      9403.500  65824.500       EN  Mt Discovery Ulti  Mountain Bike
# 2     11921.000  83447.000       EN  Mt Discovery Ulti  Mountain Bike
# 3      8911.125  62377.875       EN  Mt Discovery Ulti  Mountain Bike
# 4     13743.375  96203.625       EN  Mt Discovery Ulti  Mountain Bike
# ...         ...        ...      ...                ...            ...
# 997   11327.625  54428.500       EN         Roady 1003      Road Bike
# 998   12094.875  45402.875       EN         Roady 1003      Road Bike
# 999   12723.250  51782.500       EN         Roady 1003      Road Bike
# 1000   9633.125  36311.625       EN         Roady 1003      Road Bike
# 1001  12504.500  12956.125       EN         Roady 1003      Road Bike
#
#                   deliverydate
# 0     2018-03-10T17:00:00.000Z
# 1     2018-02-22T17:00:00.000Z
# 2     2018-03-04T17:00:00.000Z
# 3     2018-04-01T17:00:00.000Z
# 4     2018-03-24T17:00:00.000Z
# ...                        ...
# 997   2018-10-06T17:00:00.000Z
# 998   2018-10-15T17:00:00.000Z
# 999   2018-10-30T17:00:00.000Z
# 1000  2018-10-27T17:00:00.000Z
# 1001  2018-11-25T17:00:00.000Z
#
# [1002 rows x 16 columns]

# %%
total_grossamount = df['grossamount'].sum()
total_netamount = df['netamount'].sum()

print(f'Total Gross Amount: {total_grossamount}')
print(f'Total Net Amount: {total_netamount}')
# Out:
# Total Gross Amount: 63281659
# Total Net Amount: 52897606.125

# %%
sales_by_product = df.groupby('productid')['grossamount'].sum()
print(sales_by_product)
# Out:
# productid
# BX-1011    1549641
# BX-1012     863248
# BX-1013    2709677
# BX-1014    1364029
# BX-1015    2225064
# BX-1016    1229174
# CB-1161    1877688
# CB-1162     962501
# CB-1163    2413754
# CC-1021    1750758
# CC-1022    1096296
# CC-1023    2376364
# DB-1081    1938762
# DB-1082    1064792
# DB-1083    1626310
# EB-1131    1609280
# EB-1132    1680929
# EB-1133    1201857
# EB-1134    2638960
# EB-1135    1462070
# EB-1136    1253696
# EB-1137    1372275
# HB-1171    1009620
# HB-1172    1224139
# HB-1173    1824643
# HB-1174    1756850
# HB-1175    1505521
# HB-1176    1355761
# MB-1031    1029412
# MB-1032     881049
# MB-1033    2009445
# MB-1034    1491108
# RC-1051    1115598
# RC-1052    1395638
# RC-1053     936753
# RC-1054    1237230
# RC-1055    1906235
# RC-1056    1524544
# RC-1057    1327341
# RO-1001    1298398
# RO-1002     944389
# RO-1003    1240860
# Name: grossamount, dtype: int64

# %%
total_quantity_sold = df['quantity'].sum()
print(f'Total Quantity Sold: {total_quantity_sold}')
# Out:
# Total Quantity Sold: 5498

# %%
import matplotlib.pyplot as plt

# Visualisasi total penjualan per produk
sales_by_product.plot(kind='bar')
plt.title('Total Penjualan per Produk')
plt.xlabel('Product ID')
plt.ylabel('Total Gross Amount')
plt.show()

# %%
quantity_by_product = df.groupby('productid')['quantity'].sum()
quantity_by_product.plot(kind='bar', color='green')
plt.title('Jumlah Penjualan (Quantity) per Produk')
plt.xlabel('Product ID')
plt.ylabel('Total Quantity Sold')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], bins=20, kde=True, color='purple')
plt.title('Distribusi Harga Produk')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()
